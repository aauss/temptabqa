# %%
import os
from IPython.display import display, HTML

import numpy as np
import pandas as pd

# %% [markdown]
# # Investigating claims on performance made in the paper
# LLMs perform worse on the proposed TempTabQA dataset than humans. The authors split data into a head and tail set, i.e., into more common and less common domains. Of all LLMs, GPT performs the best. Transforming tables to knowledge graphs improves performance further.
#
# Key claims I want to investigate are:
# - LLMs perform better in head set than in tail set. Human performance roughly similar.
# - _How many_ questions are the hardest for humans. _Who_ questions are the hardest for LLMs
# - LLMs and humans struggle with _summation_, _difference_, and _comparison_ questions.
# - Explicit time-related questions are harder then implicit questions.
# - Money, and person-related tail questions are hard for LLMs and humans.

# %% [markdown]
# ## Inspect training, head, and tail datasets
# In the following, I will start with inspecting the training data. Later, I look into the head and tail dataset where the head set is supposed to cover more common domains and where the tail data set is supposed to cover less common domains.

# %% [markdown]
# ### Training data

# %%
df_train = pd.read_csv("../../data/maindata/qapairs/train-set/train-set.csv", index_col=0)

# %%
df_train.head()
# Out:
#                                             question             answer  \
# 0  How many years prior to Davis's death did she ...                 57
# 1  How much longer was Davis married to Gary Merr...            7 years
# 2  How long after Davis career began did she take...                  6
# 3            Who was Bette Davis married to in 1942?  Arthur Farnsworth
# 4  When was the first time that Bette Davis becam...               1943
#
#   category  table_id
# 0    actor         4
# 1    actor         4
# 2    actor         4
# 3    actor         4
# 4    actor         4

# %%
df_train.loc[:, "category"].unique()
# Out:
# array(['actor', 'swimming', 'wrestling', 'empire', 'legislature',
#        'footballer', 'tennis', 'golf', 'rugby', 'nba', 'volleyball',
#        'emperor', 'badminton', 'tabletennis', 'album', 'civil war',
#        'conference', 'aircraft', 'economy', 'court', 'racing',
#        'car driver', 'curling', 'nobel', 'painter', 'scientist', 'person',
#        'body builder', 'christian leader', 'musician', 'baseball',
#        'lacrosse', 'country', 'space probe', 'railway', 'football',
#        'handball', 'athelete', 'martial artist', 'nfl', 'ice hockey',
#        'basketball', 'company', 'website', 'university', 'stadium',
#        'launchpad', 'sailor', 'book', 'skier', 'church', 'monument',
#        'figure skating', 'office holder', 'song', 'concert', 'painting',
#        'military conflict', 'war/conflict', 'current war', 'earthquake',
#        'space program', 'music', 'character', 'movie', 'show',
#        'rail line', 'agency', 'national cricket team', 'board game',
#        'game', 'national football team', 'cricket team'], dtype=object)

# %%
df_train.shape
# Out:
# (7680, 4)

# %%
df_train.drop_duplicates(subset=["question", "answer"]).shape
# Out:
# (7299, 4)

# %%
def remove_persons_and_duplicates(df: pd.DataFrame) -> pd.DataFrame:
    return df.drop_duplicates(subset=["question", "answer"]).query(
        "category.isin(['empire', 'legislature', 'emperor', 'album', 'civil war', 'conference', 'aircraft','economy', 'court', 'nobel', 'country', 'space probe', 'railway', 'company','website', 'university', 'stadium', 'launchpad',  'book', 'church', 'monument', 'office holder','song', 'concert', 'painting', 'military conflict', 'war/conflict','current war', 'earthquake', 'space program', 'music', 'character','movie', 'show', 'rail line', 'agency','board game', 'game'])"
    )

# %%
df_without_persons = df_train.pipe(remove_persons_and_duplicates)

# %%
df_without_persons.groupby("category").sample(1)
# Out:
#                                                question  \
# 7213  How many total child agencies are there in all...
# 1190  What was the first year that pilots were able ...
# 6256  How many singles were released on the Death Ma...
# 7257  How many years were between when FASA was firs...
# 4467        In what year did Animal Farm get published?
# 6982               What year did Lassie release on CBS?
# 4594         What is the Length of  All Saints’ Church?
# 6512  Who was the leader of UK after 2 years of Mala...
# 3877               In what year was DollarTree founded?
# 6815    When did the Beautiful Trauma World Tour start?
# 1164  How many years before the13th Commonwealth Pri...
# 2695    How many years ago was DPRK admitted to the UN?
# 1342  Who is the deputy president of Supreme Court o...
# 6535  How long after the start of the Oromo conflict...
# 6719        When did uttarkashi earthquake was occured?
# 1303  What year did Economy of Guinea-Bissau foreign...
# 4841  How many years prior to his death did Ashoka s...
# 2749  How long was the Pax Mongolica of the Great Mo...
# 7355  When was the most recent edition of Cyberpunk ...
# 4048            How many associated rockets were there?
# 1111  All leadership positions currently held assume...
# 6336  Where is the situation of Part of the Syrian C...
# 6187  How many years were between when building star...
# 6989  How much money did Jurassic Park make at the b...
# 6951  In what year was 3AM being recorded in the stu...
# 5576  How many years before his death did Ernest Rut...
# 5902  What year did Morgan Carroll become Chair of t...
# 6313  The \tNationalmuseum in Stockholm opened in wh...
# 7043         Who is operator of Aigle–Sépey–Diablerets?
# 3008  How many passengers travelled through Gobela s...
# 7011       What was the total run time of each episode?
# 6948        What single was released after 3AM in 1998?
# 2953                How long did the mission go on for?
# 6872  What was the difference in cost between 1967 a...
# 3969  For how many years in total has the Al-Shaab I...
# 3905                     In what year was Penn founded?
# 6502   How long did the kachin first conflict happened?
# 4056                     Who is founders of Vimeo, Inc?
#
#                                                  answer           category  \
# 7213                                                 69             agency
# 1190                                               1913           aircraft
# 6256                                                  3              album
# 7257                                                 23         board game
# 4467                                               1945               book
# 6982                                               1954          character
# 4594                                    120 feet (37 m)             church
# 6512                                     Clement Attlee          civil war
# 3877                                               1986            company
# 6815                                      March 1, 2018            concert
# 1164                                                  2         conference
# 2695                                           21 years            country
# 1342                                         Xola Petse              court
# 6535                                            2 years        current war
# 6719  In 20 October 1991 the uttarkashi earthquake w...         earthquake
# 1303                                               2017            economy
# 4841                                            0 years            emperor
# 2749                                          100 years             empire
# 7355                                               2020               game
# 4048                                              Eight          launchpad
# 1111                                    August 16, 2020        legislature
# 6336  Situation in the Latakia Governorate in August...  military conflict
# 6187                                                 98           monument
# 6989                              1.034 Billion dollars              movie
# 6951                                               1996              music
# 5576                                           18 years              nobel
# 5902                                               2017      office holder
# 6313                                               1705           painting
# 7043                     Transports Publics du Chablais          rail line
# 3008                                            574,708            railway
# 7011                                         50 minutes               show
# 6948                                         Real World               song
# 2953                          44 years 9 months 27 days        space probe
# 6872                                       $6.6 Billion      space program
# 3969                                                  5            stadium
# 3905                                               1740         university
# 6502                       33 years, 2 weeks and 5 days       war/conflict
# 4056                           Zach Klein, Jake Lodwick            website
#
#       table_id
# 7213      1140
# 1190       225
# 6256       950
# 7257      1150
# 4467       701
# 6982      1076
# 4594       722
# 6512       996
# 3877       602
# 6815      1053
# 1164       220
# 2695       420
# 1342       255
# 6535       999
# 6719      1040
# 1303       245
# 4841       757
# 2749       428
# 7355      1168
# 4048       631
# 1111       191
# 6336       969
# 6187       940
# 6989      1080
# 6951      1073
# 5576       860
# 5902       898
# 6313       961
# 7043      1093
# 3008       462
# 7011      1082
# 6948      1072
# 2953       453
# 6872      1060
# 3969       616
# 3905       608
# 6502       994
# 4056       633

# %% [markdown]
# ### Head test set

# %%
df_head = pd.read_csv("../../data/maindata/qapairs/head-set/head-set.csv", index_col=0)
df_head.head()
# Out:
#                                             question         answer category  \
# 0  How many years did Art Carney as actor since 1...       54 Years    actor
# 1          Who was the spouse of Art Carney in 1970?  Barbara Isaac    actor
# 2  How many total years was Art Carney married to...       28 years    actor
# 3  Which spouse was Art Carney married to the least?  Barbara Isaac    actor
# 4  Who was Art Carney married to when he served i...     Jean Myers    actor
#
#    table_id
# 0         2
# 1         2
# 2         2
# 3         2
# 4         2

# %%
df_head.shape
# Out:
# (1851, 4)

# %%
df_head_without_persons = df_head.pipe(remove_persons_and_duplicates)

# %%
df_head_without_persons.groupby("category").sample(1)
# Out:
#                                                question  \
# 1719  Which year formed in Coordination Center for E...
# 243   How many years did B-24 Skua was in active ser...
# 1390  How many labels issued Confessions of a Danger...
# 1784   When was the first edition of Atlantis released?
# 1351  How long was  Dick King-Smith married to his s...
# 1661  What was the last year the Monks was portrayed...
# 1108                     When Valen kapell  was closed?
# 1413  How many years did Libya supported to Ethiopia...
# 893   Is there more or less employess at AT&T in 202...
# 1526  How many shows was showed in Europe and Austra...
# 591   How long after the French occupation of Algeri...
# 318   What is the number of other positions in the S...
# 1428  How many leaders or commanders began their rol...
# 1509  How many peoples dead, injured and homeless in...
# 284            What were the exports for Japan in 2021?
# 198   How old was Bayinnaung we he began his reign a...
# 52    How long after the constitution was adopted wa...
# 1818  What was the name of the 3rd Edition of Fate C...
# 967                          How many proton launchces?
# 1373  How many years after Anthony Pollina became Se...
# 1448  How much longer was Mauritania a belligerent t...
# 939   What was the opening date of the New York Stoc...
# 1594            What year did the movie 8 mile release?
# 1575  How many years passed between the first and la...
# 528     how many spouses does Albert A. Michelson have?
# 1324  How old was Aslam Watanjar when he finally sto...
# 1624  what is the Number of tracks of Portadown/Newr...
# 626   What events took place during the same month t...
# 1619  How long was Robert K. Silverstein a producer ...
# 1587  who is song writers name of Money Don't Matter...
# 1847              How many years did the Ingenuity fly?
# 1708  How many years separate the X-15's first fligh...
# 925   How many years passed between the ground break...
# 917   How many years was Yale University known as Co...
# 897              When is Ambassadors Group was founded?
#
#                                         answer           category  table_id
# 1719                                      1937             agency      1139
# 243                                    3 Years           aircraft       226
# 1390                                       two              album       948
# 1784                                      1984         board game      1163
# 1351                                  10 years               book       929
# 1661                                      2007          character      1104
# 1108                                 1873-1949             church       715
# 1413                                   8 Years          civil war       979
# 893                                       less            company       597
# 1526                                        29            concert      1054
# 591                                  132 years            country       436
# 318                                         13              court       257
# 1428                                         2        current war      1006
# 1509  119 dead, 1,053 injured, 15,000 homeless         earthquake      1047
# 284                           $728.931 billion            economy       248
# 198                                         48            emperor       119
# 52                                    44 years             empire        22
# 1818                     Spirit of the Century               game      1175
# 967                                         63          launchpad       629
# 1373                                        10        legislature       936
# 1448                                   3 years  military conflict      1014
# 939                               May 17, 1792           monument       626
# 1594                                      2002              movie      1077
# 1575                                         3              music      1071
# 528                                          2              nobel       370
# 1324                                        46      office holder       913
# 1624                              Double track          rail line      1092
# 626                                     closed            railway       465
# 1619                                        10               show      1085
# 1587                   Prince and Rosie Gaines               song      1075
# 1847                                    1 year        space probe      1206
# 1708                                   9 years      space program      1132
# 925                                          2            stadium       621
# 917                                   17 years         university       611
# 897                 Spokane, Washington (1967)            website       600

# %%
diff_cat_train_head = np.setdiff1d(
    df_train.loc[:, "category"].unique(), df_head.loc[:, "category"].unique()
)
diff_cat_train_head
# Out:
# array(['conference', 'football', 'painting', 'war/conflict'], dtype=object)

# %%
diff_cat_head_train = np.setdiff1d(
    df_head.loc[:, "category"].unique(), df_train.loc[:, "category"].unique()
)
diff_cat_head_train
# Out:
# array(['event', 'fighter', 'navy vessel', 'politician'], dtype=object)

# %% [markdown]
# ### Tail test set

# %%
df_tail = pd.read_csv("../../data/maindata/qapairs/tail-set/tail-set.csv", index_col=0)
df_tail.head()
# Out:
#                                             question     answer category  \
# 0  What was the age when Jenson Button best finis...  Age of 38       f1
# 1  What was Jenson Button's age when he won the S...         38       f1
# 2  How long did it take Jenson Button to win his ...    9 years       f1
# 3  Where did Jenson Button compete 5 years before...     Brazil       f1
# 4  For how many years did Jenson Button's profess...   17 years       f1
#
#    table_id
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
df_tail.category.unique()
# Out:
# array(['f1', 'time zone', 'hockey', 'cricket', 'cycling', 'squash',
#        'sumo', 'political party', 'sports event', 'holiday', 'ship',
#        'orbitor', 'boxing', 'terrorist orgnization', 'cyclone',
#        'proxy war', 'army', 'planet', 'disease'], dtype=object)

# %%
df_tail.groupby("category").sample(1)
# Out:
#                                                question  \
# 959   How many years did First Lebanon War was held ...
# 552   How much longer did Yamamoto play for Kamatama...
# 615   How old was Brian Lara when he joined West Ind...
# 101   What team did Valverde ride for the year he wo...
# 740                      How strong was Hurricane Ivan?
# 1030  How much time elapsed between the first report...
# 34    How many years are between Barrichello's best ...
# 661   How old was Lombi when won gold at the Pan Ame...
# 436   How many days later does Mardi Gras start in 2...
# 547   How many month left did ExoMars was planned in...
# 997     What is the orbital period of Neptune in years?
# 699   How many seats does Rajya Sabha and Lok Sabha ...
# 790   How many years longer was Arnaldo Schulz a lea...
# 465   How long after the HMSArgyll was laid down was...
# 323   Where was the location one year before the Wom...
# 189   When was the first time that Paul Coll got any...
# 210    How old was Chiyonofuji Mitsugu when he retired?
# 679   Who was the largest country that was an oppone...
# 23    What is the Current time in Newfoundland Time ...
#
#                               answer               category  table_id
# 959                          3 Years                   army      1119
# 552                          3 years                 boxing       484
# 615                               21                cricket       528
# 101               Kelme–Costa Blanca                cycling        99
# 740     Category 5 Hurricane (SSHWS)                cyclone       958
# 1030                        14 days.                disease      1205
# 34                                 2                     f1        51
# 661                               24                 hockey       680
# 436                           5 days                holiday       218
# 547                    9 months left                orbitor       461
# 997                         164.8 yr                 planet      1138
# 699                               89        political party       931
# 790                                2              proxy war      1000
# 465        four years and two months                   ship       223
# 323                           Prague           sports event       200
# 189                             2018                 squash       109
# 210                     36 years old                   sumo       131
# 679                              USA  terrorist orgnization       711
# 23    Sunday, 10 July 2022, 11:26 pm              time zone        35

# %%
df_train.query("category.isin(@df_tail.category.unique())")
# Out:
# Empty DataFrame
# Columns: [question, answer, category, table_id]
# Index: []

# %%
df_head.query("category.isin(@df_tail.category.unique())")
# Out:
# Empty DataFrame
# Columns: [question, answer, category, table_id]
# Index: []

# %%
df_tail = df_tail.drop_duplicates()
# Table contains duplicate questions. Either, because answers are slightly different or because category is different
df_tail[df_tail.loc[:, "question"].duplicated(keep=False)]
# Out:
#                                                question  \
# 198         How old was Tarek Momen when he turned pro?
# 202         How old was Tarek Momen when he turned pro?
# 219      How old was Futabayama Sadaji when he retired?
# 222      How old was Futabayama Sadaji when he retired?
# 270   How old was Aminishiki Ryūji when he made his ...
# 275   How old was Aminishiki Ryūji when he made his ...
# 279   How many total years (terms) does Joe Biden ho...
# 280          What positions did Joe Biden hold in 2008?
# 287   Who was Joe Biden married to when he was first...
# 293          What positions did Joe Biden hold in 2008?
# 295   How many parties does Joe’s Biden’s is associa...
# 296   What was the relationship status of Joe Biden ...
# 297   How many total years (terms) does Joe Biden ho...
# 304   How many years after the second marriage did J...
# 305   What was the relationship status of Joe Biden ...
# 342   How many parties does Joe’s Biden’s is associa...
# 343   Who was Joe Biden married to when he was first...
# 344       Who was the better half of Joe Biden in 1970?
# 349   How many total years (terms) does Joe Biden ho...
# 443       Who was the better half of Joe Biden in 1970?
# 444   How many years after the second marriage did J...
# 445          What positions did Joe Biden hold in 2008?
# 468   How many years does HMSAstute is service in UK...
# 730   What was the relationship status of Joe Biden ...
# 731   Who was Joe Biden married to when he was first...
# 732   At what age does Joe Biden join the democratic...
# 841   Who was Joe Biden married to when he was first...
# 842   Who was the US senator from Delaware in Dec 1972?
# 843       Who was the better half of Joe Biden in 1970?
# 845   How many total years (terms) does Joe Biden ho...
# 850   Who was the US senator from Delaware in Dec 1972?
# 854   Who was the US senator from Delaware in Dec 1972?
# 855          What positions did Joe Biden hold in 2008?
# 856   How many years after the second marriage did J...
# 862   At what age does Joe Biden join the democratic...
# 863   How many parties does Joe’s Biden’s is associa...
# 900   How many years does HMSAstute is service in UK...
# 916          What positions did Joe Biden hold in 2008?
# 922   How many parties does Joe’s Biden’s is associa...
# 923   At what age does Joe Biden join the democratic...
# 932   Who was Joe Biden married to when he was first...
# 935   What was the relationship status of Joe Biden ...
# 936       Who was the better half of Joe Biden in 1970?
# 937   At what age does Joe Biden join the democratic...
# 941   Who was the US senator from Delaware in Dec 1972?
# 947   How many years after the second marriage did J...
# 953   Who was the US senator from Delaware in Dec 1972?
# 956       Who was the better half of Joe Biden in 1970?
# 957   How many years after the second marriage did J...
# 965   How many years after the second marriage did J...
# 966   What was the relationship status of Joe Biden ...
# 967   Who was the US senator from Delaware in Dec 1972?
# 1026  Who was the US senator from Delaware in Dec 1972?
# 1027  What was the relationship status of Joe Biden ...
# 1028  How many total years (terms) does Joe Biden ho...
#
#                                                  answer         category  \
# 198                                                  17           squash
# 202                                        17 years old           squash
# 219                                        33 years old             sumo
# 222                                                  33             sumo
# 270                                        19 years old             sumo
# 275                                                  19             sumo
# 279                                   6 years (2 terms)  political party
# 280   The United States Senator from Delaware, Chair...  political party
# 287                                           Unmarried  political party
# 293   The United States Senator from Delaware, Chair...  political party
# 295                                                 one  political party
# 296                              Married to Jill Jocabs  political party
# 297                                   6 years (2 terms)  political party
# 304                                            44 years  political party
# 305                              Married to Jill Jocabs  political party
# 342                                                 one          holiday
# 343                                           Unmarried          holiday
# 344                                       Neilia Hunter          holiday
# 349                                   6 years (2 terms)          holiday
# 443                                       Neilia Hunter          holiday
# 444                                            44 years          holiday
# 445   The United States Senator from Delaware, Chair...          holiday
# 468                                            28 Years             ship
# 730                              Married to Jill Jocabs          cyclone
# 731                                           Unmarried          cyclone
# 732                                                  27          cyclone
# 841                                           Unmarried          cyclone
# 842                                      J. Caleb Boggs          cyclone
# 843                                       Neilia Hunter          cyclone
# 845                                   6 years (2 terms)          cyclone
# 850                                   A. J. Caleb Boggs          cyclone
# 854                                      J. Caleb Boggs          cyclone
# 855   The United States Senator from Delaware, Chair...          cyclone
# 856                                            44 years          cyclone
# 862                                                  27          cyclone
# 863                                                 one          cyclone
# 900                                 8 Years (from 2014)             ship
# 916   The United States Senator from Delaware, Chair...             army
# 922                                                 one             army
# 923                                                  27             army
# 932                                           Unmarried             army
# 935                              Married to Jill Jocabs             army
# 936                                       Neilia Hunter             army
# 937                                                  27             army
# 941                                      J. Caleb Boggs             army
# 947                                            44 years             army
# 953                                   A. J. Caleb Boggs             army
# 956                                       Neilia Hunter             army
# 957                                            44 years             army
# 965                                            44 years             army
# 966                              Married to Jill Jocabs             army
# 967                                      J. Caleb Boggs             army
# 1026                                     J. Caleb Boggs          disease
# 1027                             Married to Jill Jocabs          disease
# 1028                                  6 years (2 terms)          disease
#
#       table_id
# 198        110
# 202        110
# 219        134
# 222        134
# 270        180
# 275        180
# 279        182
# 280        182
# 287        182
# 293        183
# 295        183
# 296        183
# 297        184
# 304        184
# 305        184
# 342        206
# 343        206
# 344        206
# 349        206
# 443        219
# 444        219
# 445        219
# 468        224
# 730        958
# 731        958
# 732        958
# 841       1090
# 842       1090
# 843       1090
# 845       1090
# 850       1091
# 854       1091
# 855       1091
# 856       1091
# 862       1091
# 863       1091
# 900       1114
# 916       1116
# 922       1116
# 923       1116
# 932       1118
# 935       1118
# 936       1118
# 937       1118
# 941       1118
# 947       1118
# 953       1119
# 956       1119
# 957       1119
# 965       1120
# 966       1120
# 967       1120
# 1026      1204
# 1027      1204
# 1028      1204

# %%
# Duplicates due to 1:n relationship between question and category, and question and table_id
df_tail[
    df_tail.duplicated(subset=["question", "answer", "category"], keep=False)
].sort_values(by="question")
# Out:
#                                               question  \
# 937  At what age does Joe Biden join the democratic...
# 923  At what age does Joe Biden join the democratic...
# 862  At what age does Joe Biden join the democratic...
# 732  At what age does Joe Biden join the democratic...
# 279  How many total years (terms) does Joe Biden ho...
# 297  How many total years (terms) does Joe Biden ho...
# 965  How many years after the second marriage did J...
# 957  How many years after the second marriage did J...
# 947  How many years after the second marriage did J...
# 293         What positions did Joe Biden hold in 2008?
# 280         What positions did Joe Biden hold in 2008?
# 305  What was the relationship status of Joe Biden ...
# 296  What was the relationship status of Joe Biden ...
# 966  What was the relationship status of Joe Biden ...
# 935  What was the relationship status of Joe Biden ...
# 841  Who was Joe Biden married to when he was first...
# 731  Who was Joe Biden married to when he was first...
# 941  Who was the US senator from Delaware in Dec 1972?
# 854  Who was the US senator from Delaware in Dec 1972?
# 842  Who was the US senator from Delaware in Dec 1972?
# 967  Who was the US senator from Delaware in Dec 1972?
# 956      Who was the better half of Joe Biden in 1970?
# 443      Who was the better half of Joe Biden in 1970?
# 344      Who was the better half of Joe Biden in 1970?
# 936      Who was the better half of Joe Biden in 1970?
#
#                                                 answer         category  \
# 937                                                 27             army
# 923                                                 27             army
# 862                                                 27          cyclone
# 732                                                 27          cyclone
# 279                                  6 years (2 terms)  political party
# 297                                  6 years (2 terms)  political party
# 965                                           44 years             army
# 957                                           44 years             army
# 947                                           44 years             army
# 293  The United States Senator from Delaware, Chair...  political party
# 280  The United States Senator from Delaware, Chair...  political party
# 305                             Married to Jill Jocabs  political party
# 296                             Married to Jill Jocabs  political party
# 966                             Married to Jill Jocabs             army
# 935                             Married to Jill Jocabs             army
# 841                                          Unmarried          cyclone
# 731                                          Unmarried          cyclone
# 941                                     J. Caleb Boggs             army
# 854                                     J. Caleb Boggs          cyclone
# 842                                     J. Caleb Boggs          cyclone
# 967                                     J. Caleb Boggs             army
# 956                                      Neilia Hunter             army
# 443                                      Neilia Hunter          holiday
# 344                                      Neilia Hunter          holiday
# 936                                      Neilia Hunter             army
#
#      table_id
# 937      1118
# 923      1116
# 862      1091
# 732       958
# 279       182
# 297       184
# 965      1120
# 957      1119
# 947      1118
# 293       183
# 280       182
# 305       184
# 296       183
# 966      1120
# 935      1118
# 841      1090
# 731       958
# 941      1118
# 854      1091
# 842      1090
# 967      1120
# 956      1119
# 443       219
# 344       206
# 936      1118

# %%
# Duplicates due to different answers per question
df_tail[df_tail.duplicated(subset=["question", "table_id"], keep=False)].sort_values(
    by="question"
)
# Out:
#                                               question             answer  \
# 270  How old was Aminishiki Ryūji when he made his ...       19 years old
# 275  How old was Aminishiki Ryūji when he made his ...                 19
# 219     How old was Futabayama Sadaji when he retired?       33 years old
# 222     How old was Futabayama Sadaji when he retired?                 33
# 198        How old was Tarek Momen when he turned pro?                 17
# 202        How old was Tarek Momen when he turned pro?       17 years old
# 850  Who was the US senator from Delaware in Dec 1972?  A. J. Caleb Boggs
# 854  Who was the US senator from Delaware in Dec 1972?     J. Caleb Boggs
#
#     category  table_id
# 270     sumo       180
# 275     sumo       180
# 219     sumo       134
# 222     sumo       134
# 198   squash       110
# 202   squash       110
# 850  cyclone      1091
# 854  cyclone      1091

# %% [markdown]
# ## Inspect the author's data analysis
# After running the dataAnalysis.py script, I created a .csv that contains descriptors of the questions raised in the training set such as whether the questions is implicit or explicit, which temporal operation is required and so on.

# %%
df_analysis = pd.read_csv(
    "../../data/maindata/qapairs/train-set/train-set_analysis.csv"
).iloc[:, 2:]
df_analysis.head()
# Out:
#                                             question             answer  \
# 0  How many years prior to Davis's death did she ...                 57
# 1  How much longer was Davis married to Gary Merr...            7 years
# 2  How long after Davis career began did she take...                  6
# 3            Who was Bette Davis married to in 1942?  Arthur Farnsworth
# 4  When was the first time that Bette Davis becam...               1943
#
#   category  table_id  explicit  implicit  before_related  after_related  \
# 0    actor         4      True     False            True          False
# 1    actor         4     False      True           False          False
# 2    actor         4     False      True           False           True
# 3    actor         4      True     False           False          False
# 4    actor         4     False      True           False          False
#
#    duration_related  max_operator  min_operator  count_operator  sum_operator  \
# 0             False         False         False            True         False
# 1              True         False         False           False         False
# 2             False         False         False           False         False
# 3             False         False         False           False         False
# 4             False         False         False           False         False
#
#    difference_operator  average_operator  comparison_operator  ordinal  \
# 0                False             False                False    False
# 1                False             False                False    False
# 2                False             False                False    False
# 3                False             False                False    False
# 4                False             False                False     True
#
#   answer_type
# 0       COUNT
# 1    TEMPORAL
# 2     UNKNOWN
# 3      PERSON
# 4    TEMPORAL

# %%
df_analysis.columns
# Out:
# Index(['question', 'answer', 'category', 'table_id', 'explicit', 'implicit',
#        'before_related', 'after_related', 'duration_related', 'max_operator',
#        'min_operator', 'count_operator', 'sum_operator', 'difference_operator',
#        'average_operator', 'comparison_operator', 'ordinal', 'answer_type'],
#       dtype='object')

# %%
df_analysis.loc[:, "answer_type"].unique()
# Out:
# array(['COUNT', 'TEMPORAL', 'UNKNOWN', 'PERSON', 'AGE', 'PLACE',
#        'PERCENTAGE', 'ORDINAL', 'YES/NO', 'ORGANIZATION', 'PRODUCT',
#        'MONEY'], dtype=object)

# %% [markdown]
# ### _How many_ questions are the hardest for humans. _Who_ questions are the hardest for LLMs
# Let's investigate how these questions look like and what they have in common.
#
# `dataAnalysis.py` does not produce a category _how many_ or _who_. When investigating the regexes in the script, both categories `count_operator` and `duration_related` match _how many_. When looking for _who_ matching regexes, only answer types were classified. Therefore, I assume the analysis must have been using simple string matching.

# %% [markdown]
# #### Let's start with looking at the GPT 4 prediction for the tail data set.
# We must load both datasets, remove duplicates and find tail questions by merging them with the GPT4 answers. Afterwards, we will search for _how many_ and _who_ questions to inspect the data further.

# %%
df_gpt4 = pd.read_csv(
    "../../models/predictions/gpt4/fewshot_with_reasoning/outdomain_eval_gpt_4_few_shot_with_reasoning_single.csv"
)
df_gpt4.head()
# Out:
#                                                table  \
# 0  <html><body><table class="infobox biography vc...
# 1  <html><body><table class="infobox biography vc...
# 2  <html><body><table class="infobox biography vc...
# 3  <html><body><table class="infobox biography vc...
# 4  <html><body><table class="infobox biography vc...
#
#                                     predicted_answer        actual_answer  \
# 0  Formula One && Five years before his Super GT ...               Brazil
# 1  20 years old && Button began his Formula One c...                   20
# 2  United Kingdom && Jenson Button's nationality ...              England
# 3  2000 && He first entered the Australian Grand ...                 2000
# 4  10 years ago && Jenson Button last won the Bra...  10 Years ago (2012)
#
#                                             question
# 0  Where did Jenson Button compete 5 years before...
# 1  How old was Jenson Button when he began his pr...
# 2  Which country did Jenson Button participated i...
# 3  When did Jenson Button first enter into the Au...
# 4  How many years ago did Jenson Button last won ...

# %%
def inline_render_html(html_str):
    return f'<div style="border: 1px solid #ddd; padding: 5px;">{html_str}</div>'


def html_render_df(df, html_col="table"):
    return df.style.format({html_col: inline_render_html}).set_properties(
        subset=["table"], **{"text-align": "left"}
    )


html_render_df(df_gpt4.tail(1))
# Out:
# <style type="text/css">
# #T_dbfc0_row0_col0 {
#   text-align: left;
# }
# </style>
# <table id="T_dbfc0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dbfc0_level0_col0" class="col_heading level0 col0" >table</th>
#       <th id="T_dbfc0_level0_col1" class="col_heading level0 col1" >predicted_answer</th>
#       <th id="T_dbfc0_level0_col2" class="col_heading level0 col2" >actual_answer</th>
#       <th id="T_dbfc0_level0_col3" class="col_heading level0 col3" >question</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dbfc0_level0_row0" class="row_heading level0 row0" >1026</th>
#       <td id="T_dbfc0_row0_col0" class="data row0 col0" ><div style="border: 1px solid #ddd; padding: 5px;"><table class="infobox"><tbody><tr><th class="infobox-above" colspan="2" style="background:#ffcccb">White House COVID-19 outbreak</th></tr><tr><td class="infobox-image" colspan="2" style="border-bottom:#aaa 1px solid"><img alt="President Trump Nominates Judge Amy Coney Barrett for Associate Justice of the U.S. Supreme Court (50397097478).jpg" data-file-height="2000" data-file-width="3000" decoding="async" height="147" src="https://upload.wikimedia.org/wikipedia/commons/thumb/9/97/President_Trump_Nominates_Judge_Amy_Coney_Barrett_for_Associate_Justice_of_the_U.S._Supreme_Court_%2850397097478%29.jpg/220px-President_Trump_Nominates_Judge_Amy_Coney_Barrett_for_Associate_Justice_of_the_U.S._Supreme_Court_%2850397097478%29.jpg" srcset="https://upload.wikimedia.org/wikipedia/commons/thumb/9/97/President_Trump_Nominates_Judge_Amy_Coney_Barrett_for_Associate_Justice_of_the_U.S._Supreme_Court_%2850397097478%29.jpg/330px-President_Trump_Nominates_Judge_Amy_Coney_Barrett_for_Associate_Justice_of_the_U.S._Supreme_Court_%2850397097478%29.jpg 1.5x,https: //upload.wikimedia.org/wikipedia/commons/thumb/9/97/President_Trump_Nominates_Judge_Amy_Coney_Barrett_for_Associate_Justice_of_the_U.S._Supreme_Court_%2850397097478%29.jpg/440px-President_Trump_Nominates_Judge_Amy_Coney_Barrett_for_Associate_Justice_of_the_U.S._Supreme_Court_%2850397097478%29.jpg 2x" width="220"><div class="infobox-caption" style="text-align:left"><div class="center" style="width:auto;margin-left:auto;margin-right:auto">President Donald Trump speaking during the event held to announce Amy Coney Barrett's nomination to the Supreme Court in the White House Rose Garden.</div></div></td></tr><tr><th class="infobox-label" scope="row">Disease</th><td class="infobox-data">COVID-19</td></tr><tr><th class="infobox-label" scope="row">Virus strain</th><td class="infobox-data">SARS-CoV-2</td></tr><tr><th class="infobox-label" scope="row">Location</th><td class="infobox-data">White House, Washington, D.C., United States</td></tr><tr><th class="infobox-label" scope="row">First reported</th><td class="infobox-data">October 1, 2020</td></tr><tr><th class="infobox-label" scope="row">Index case</th><td class="infobox-data">September 30, 2020</td></tr><tr><th class="infobox-label" scope="row">Arrival date</th><td class="infobox-data">September 26, 2020<span class="noprint">; 2 years ago</span><span style="display:none"> (<span class="bday dtstart published updated">2020-09-26</span>)</span></td></tr><tr><th class="infobox-label" scope="row"><span class="nowrap">Confirmed cases</span></th><td class="infobox-data"><div class="plainlist"><ul><li><b>Total:</b>At least 53, including President Trump</li><li><b>Pre-nomination:</b>At least six as of October 14</li><li><b>Nomination:</b>At least 25 as of October 14</li><li><b>Pence staff:</b>At least 5 as of November 11</li><li><b>Election Day:</b>At least 20 as of November 11</li></ul></div></td></tr><tr><th class="infobox-label" scope="row"><span class="nowrap">Hospitalized cases</span></th><td class="infobox-data">At least one, by October 15</td></tr></tbody></table></div></td>
#       <td id="T_dbfc0_row0_col1" class="data row0 col1" >President Trump && He was the most noteworthy individual to contract Covid in the White House outbreak.</td>
#       <td id="T_dbfc0_row0_col2" class="data row0 col2" >President Trump</td>
#       <td id="T_dbfc0_row0_col3" class="data row0 col3" >Who was the most noteworthy individual to contract Covid in this?</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_gpt4.shape
# Out:
# (1027, 4)

# %%
# Answers are otherwise not easy to check for exact match
df_gpt4 = df_gpt4.assign(
    predicted_answer_short=lambda x: x["predicted_answer"]
    .str.split("&&")
    .str[0]
    .str.strip()
)

# %%
html_render_df(
    df_gpt4.query("predicted_answer_short == actual_answer")
    .sample(3, random_state=94)
    .loc[:, ["table", "question", "predicted_answer_short", "actual_answer"]]
)
# Out:
# <style type="text/css">
# #T_b5cfc_row0_col0, #T_b5cfc_row1_col0, #T_b5cfc_row2_col0 {
#   text-align: left;
# }
# </style>
# <table id="T_b5cfc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b5cfc_level0_col0" class="col_heading level0 col0" >table</th>
#       <th id="T_b5cfc_level0_col1" class="col_heading level0 col1" >question</th>
#       <th id="T_b5cfc_level0_col2" class="col_heading level0 col2" >predicted_answer_short</th>
#       <th id="T_b5cfc_level0_col3" class="col_heading level0 col3" >actual_answer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b5cfc_level0_row0" class="row_heading level0 row0" >85</th>
#       <td id="T_b5cfc_row0_col0" class="data row0 col0" ><div style="border: 1px solid #ddd; padding: 5px;"><html><body><table class="infobox vcard" style="width:25em"><caption class="infobox-title fn" style="font-size:125%"><span class="honorific-prefix" style="font-size:77%;font-weight:400">Deshabandu</span><br><span class="fn">Sanath Jayasuriya</span></caption><tbody><tr><td class="infobox-image" colspan="2"><img alt="Sanath jayasuriya portrait.jpg" data-file-height="308" data-file-width="281" decoding="async" height="241" src="https://upload.wikimedia.org/wikipedia/commons/thumb/1/16/Sanath_jayasuriya_portrait.jpg/220px-Sanath_jayasuriya_portrait.jpg" srcset="https://upload.wikimedia.org/wikipedia/commons/1/16/Sanath_jayasuriya_portrait.jpg 1.5x" width="220"><div class="infobox-caption">Jayasuriya playing for Sri Lanka in 2008</div></td></tr><tr><th class="infobox-header" colspan="2" style="background-color:#b0c4de">Personal information</th></tr><tr><th class="infobox-label" scope="row">Full name</th><td class="infobox-data nickname"><span class="fn">Sanath Teran Jayasuriya</span></td></tr><tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data"><span style="display:none">(<span class="bday">1969-06-30</span>)</span>30 June 1969<span class="noprint ForceAgeToShow">(age 52)</span><br><span class="birthplace">Matara, Ceylon</span></td></tr><tr><th class="infobox-label" scope="row">Nickname</th><td class="infobox-data nickname">Master Blaster, Little Dynamite, Matara Hurricane<br>Matara Mauler</td></tr><tr><th class="infobox-label" scope="row">Height</th><td class="infobox-data">5 ft 7 in (1.70 m)</td></tr><tr><th class="infobox-label" scope="row">Batting</th><td class="infobox-data category">Left-handed</td></tr><tr><th class="infobox-label" scope="row">Bowling</th><td class="infobox-data category">Slow left arm orthodox</td></tr><tr><th class="infobox-label" scope="row">Role</th><td class="infobox-data role">All-rounder</td></tr><tr><th class="infobox-header" colspan="2" style="background-color:#b0c4de">International information<link href="mw-data:TemplateStyles:r1066479718" rel="mw-deduplicated-inline-style"></th></tr><tr><th class="infobox-label" scope="row">National side</th><td class="infobox-data"><div class="plainlist"><ul><li>Sri Lanka (1989–2011)</li></ul></div></td></tr><tr><th class="infobox-label" scope="row">Test debut (cap 49)</th><td class="infobox-data">22 February 1991 v New Zealand</td></tr><tr><th class="infobox-label" scope="row">Last Test</th><td class="infobox-data">1 December 2007 v England</td></tr><tr><th class="infobox-label" scope="row">ODI debut (cap 58)</th><td class="infobox-data">26 December 1989 v Australia</td></tr><tr><th class="infobox-label" scope="row">Last ODI</th><td class="infobox-data">28 June 2011 v England</td></tr><tr><th class="infobox-label" scope="row">ODI shirt no.</th><td class="infobox-data">07</td></tr><tr><th class="infobox-label" scope="row">T20I debut (cap 4)</th><td class="infobox-data">15 June 2006 v England</td></tr><tr><th class="infobox-label" scope="row">Last T20I</th><td class="infobox-data">25 June 2011 v England</td></tr><tr style="display:none"><th colspan="2"></th></tr><tr><th class="infobox-header" colspan="2" style="background-color:#b0c4de">Domestic team information</th></tr><tr style="line-height:9pt"><th scope="col">Years</th><th scope="col">Team</th><link href="mw-data:TemplateStyles:r1066479718" rel="mw-deduplicated-inline-style"></tr><tr><th class="infobox-label" scope="row" style="font-weight:400;padding-right:3em"><span class="nowrap">1994–2011</span></th><td class="infobox-data">Bloomfield</td></tr><tr><th class="infobox-label" scope="row" style="font-weight:400;padding-right:3em">2005</th><td class="infobox-data">Somerset</td></tr><tr><th class="infobox-label" scope="row" style="font-weight:400;padding-right:3em">2007</th><td class="infobox-data">Lancashire</td></tr><tr><th class="infobox-label" scope="row" style="font-weight:400; ...
#       <td id="T_b5cfc_row0_col1" class="data row0 col1" >What was the third team that Sanath Jayasuriya played for?</td>
#       <td id="T_b5cfc_row0_col2" class="data row0 col2" >Lancashire</td>
#       <td id="T_b5cfc_row0_col3" class="data row0 col3" >Lancashire</td>
#     </tr>
#     <tr>
#       <th id="T_b5cfc_level0_row1" class="row_heading level0 row1" >197</th>
#       <td id="T_b5cfc_row1_col0" class="data row1 col0" ><div style="border: 1px solid #ddd; padding: 5

# %%
html_render_df(
    df_gpt4.query("predicted_answer_short == actual_answer")
    .sample(20, random_state=94)
    .loc[:, ["table", "question", "predicted_answer_short", "actual_answer"]]
)
# Out:
# <style type="text/css">
# #T_19b9c_row0_col0, #T_19b9c_row1_col0, #T_19b9c_row2_col0, #T_19b9c_row3_col0, #T_19b9c_row4_col0, #T_19b9c_row5_col0, #T_19b9c_row6_col0, #T_19b9c_row7_col0, #T_19b9c_row8_col0, #T_19b9c_row9_col0, #T_19b9c_row10_col0, #T_19b9c_row11_col0, #T_19b9c_row12_col0, #T_19b9c_row13_col0, #T_19b9c_row14_col0, #T_19b9c_row15_col0, #T_19b9c_row16_col0, #T_19b9c_row17_col0, #T_19b9c_row18_col0, #T_19b9c_row19_col0 {
#   text-align: left;
# }
# </style>
# <table id="T_19b9c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_19b9c_level0_col0" class="col_heading level0 col0" >table</th>
#       <th id="T_19b9c_level0_col1" class="col_heading level0 col1" >question</th>
#       <th id="T_19b9c_level0_col2" class="col_heading level0 col2" >predicted_answer_short</th>
#       <th id="T_19b9c_level0_col3" class="col_heading level0 col3" >actual_answer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_19b9c_level0_row0" class="row_heading level0 row0" >85</th>
#       <td id="T_19b9c_row0_col0" class="data row0 col0" ><div style="border: 1px solid #ddd; padding: 5px;"><html><body><table class="infobox vcard" style="width:25em"><caption class="infobox-title fn" style="font-size:125%"><span class="honorific-prefix" style="font-size:77%;font-weight:400">Deshabandu</span><br><span class="fn">Sanath Jayasuriya</span></caption><tbody><tr><td class="infobox-image" colspan="2"><img alt="Sanath jayasuriya portrait.jpg" data-file-height="308" data-file-width="281" decoding="async" height="241" src="https://upload.wikimedia.org/wikipedia/commons/thumb/1/16/Sanath_jayasuriya_portrait.jpg/220px-Sanath_jayasuriya_portrait.jpg" srcset="https://upload.wikimedia.org/wikipedia/commons/1/16/Sanath_jayasuriya_portrait.jpg 1.5x" width="220"><div class="infobox-caption">Jayasuriya playing for Sri Lanka in 2008</div></td></tr><tr><th class="infobox-header" colspan="2" style="background-color:#b0c4de">Personal information</th></tr><tr><th class="infobox-label" scope="row">Full name</th><td class="infobox-data nickname"><span class="fn">Sanath Teran Jayasuriya</span></td></tr><tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data"><span style="display:none">(<span class="bday">1969-06-30</span>)</span>30 June 1969<span class="noprint ForceAgeToShow">(age 52)</span><br><span class="birthplace">Matara, Ceylon</span></td></tr><tr><th class="infobox-label" scope="row">Nickname</th><td class="infobox-data nickname">Master Blaster, Little Dynamite, Matara Hurricane<br>Matara Mauler</td></tr><tr><th class="infobox-label" scope="row">Height</th><td class="infobox-data">5 ft 7 in (1.70 m)</td></tr><tr><th class="infobox-label" scope="row">Batting</th><td class="infobox-data category">Left-handed</td></tr><tr><th class="infobox-label" scope="row">Bowling</th><td class="infobox-data category">Slow left arm orthodox</td></tr><tr><th class="infobox-label" scope="row">Role</th><td class="infobox-data role">All-rounder</td></tr><tr><th class="infobox-header" colspan="2" style="background-color:#b0c4de">International information<link href="mw-data:TemplateStyles:r1066479718" rel="mw-deduplicated-inline-style"></th></tr><tr><th class="infobox-label" scope="row">National side</th><td class="infobox-data"><div class="plainlist"><ul><li>Sri Lanka (1989–2011)</li></ul></div></td></tr><tr><th class="infobox-label" scope="row">Test debut (cap 49)</th><td class="infobox-data">22 February 1991 v New Zealand</td></tr><tr><th class="infobox-label" scope="row">Last Test</th><td class="infobox-data">1 December 2007 v England</td></tr><tr><th class="infobox-label" scope="row">ODI debut (cap 58)</th><td class="infobox-data">26 December 1989 v Australia</td></tr><tr><th class="infobox-label" scope="row">Last ODI</th><td class="infobox-data">28 June 2011 v England</td></tr><tr><th class="infobox-label" scope="row">ODI shirt no.</th><td class="infobox-data">07</td></tr><tr><th class="infobox-label" scope="row">T20I debut (cap 4)</th><td class="infobox-data">15 June 2006 v England</td></tr><tr><th class="infobox-label" scope="row">Last T20I</th><td class="infobox-data">25 June 2011 v England</td></tr><tr style="display:none"><th colspan="2"></th></tr><tr><th class="infobox-header" colspan="2" style="background-color:#b0c4de">Domestic team information</th></tr><tr style="line-height:9pt"><th scope="col">Years</th><th scope="col">Team</th><link href="mw-data:TemplateStyles:r1066479718" rel="mw-deduplicated-inline-style"></tr><tr><th class="infobox-label" scope="row" style="font-weight:400;padding-right:3em"><span class="nowrap">1994–2011</span></th><td class="infobox-data">Bloomfield</td></tr><tr><th class="infobox-label" scope="row" style="font-weight:400;padding-right:3em">2005</th><td class="infobox-data">Somerset</td></tr><tr><th class="infobox-label" scope="row" style="font-weight:400;padding-right:3em">2007</th><td class="infobox-data">Lancashire</td></tr><tr><th class="infobox-label" scope="row" style="font-weight:400; ...
#       <td id="T_19b9c_row0_col1" class="data row0 col1" >What was the third team that Sanath Jayasuriya played for?<

# %%
html_render_df(
    df_gpt4.query("predicted_answer_short != actual_answer")
    .query("question.str.contains('Biden')")
    .loc[[279]]
)
# Out:
# <style type="text/css">
# #T_3ed7b_row0_col0 {
#   text-align: left;
# }
# </style>
# <table id="T_3ed7b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3ed7b_level0_col0" class="col_heading level0 col0" >table</th>
#       <th id="T_3ed7b_level0_col1" class="col_heading level0 col1" >predicted_answer</th>
#       <th id="T_3ed7b_level0_col2" class="col_heading level0 col2" >actual_answer</th>
#       <th id="T_3ed7b_level0_col3" class="col_heading level0 col3" >question</th>
#       <th id="T_3ed7b_level0_col4" class="col_heading level0 col4" >predicted_answer_short</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3ed7b_level0_row0" class="row_heading level0 row0" >279</th>
#       <td id="T_3ed7b_row0_col0" class="data row0 col0" ><div style="border: 1px solid #ddd; padding: 5px;"><html><body><table class="infobox vcard"><tbody><tr><th class="infobox-above" colspan="2" style="font-size:125%"><div style="padding-top:.3em;padding-bottom:.3em;border-top:2px solid #00b9ec;border-bottom:2px solid #00b9ec;line-height:1"><div class="fn org">Citizen Revolution Movement</div><div class="nickname" style="font-size:.8em;padding-top:.3em">Movimiento Revolución Ciudadana</div></div></th></tr><tr><td class="infobox-image logo" colspan="2" style="padding-top:.4em;padding-bottom:.3em"><img alt="Movimiento revolucion ciudadana.png" data-file-height="555" data-file-width="449" decoding="async" height="222" src="https://upload.wikimedia.org/wikipedia/commons/thumb/b/b4/Movimiento_revolucion_ciudadana.png/180px-Movimiento_revolucion_ciudadana.png" srcset="https://upload.wikimedia.org/wikipedia/commons/thumb/b/b4/Movimiento_revolucion_ciudadana.png/270px-Movimiento_revolucion_ciudadana.png 1.5x,https: //upload.wikimedia.org/wikipedia/commons/thumb/b/b4/Movimiento_revolucion_ciudadana.png/360px-Movimiento_revolucion_ciudadana.png 2x" width="180"></td></tr><tr><th class="infobox-label" scope="row" style="line-height:1.3em">Abbreviation</th><td class="infobox-data nickname" style="line-height:1.3em">RC</td></tr><tr><th class="infobox-label" scope="row" style="line-height:1.3em">Leader</th><td class="infobox-data agent" style="line-height:1.3em">Rafael Correa</td></tr><tr><th class="infobox-label" scope="row" style="line-height:1.3em">President</th><td class="infobox-data agent" style="line-height:1.3em">Marcela Aguiñaga</td></tr><tr><th class="infobox-label" scope="row" style="line-height:1.3em">General Secretary</th><td class="infobox-data agent" style="line-height:1.3em">David Villamar</td></tr><tr><th class="infobox-label" scope="row" style="line-height:1.3em">Founder</th><td class="infobox-data agent" style="line-height:1.3em">Iván Espinel</td></tr><tr><th class="infobox-label" scope="row" style="line-height:1.3em">Founded</th><td class="infobox-data" style="line-height:1.3em">2010<span style="font-size:85%">(historical)</span><br>August 2021<span style="font-size:85%">(modern)</span></td></tr><tr><th class="infobox-label" scope="row" style="line-height:1.3em">Registered</th><td class="infobox-data" style="line-height:1.3em">18 August 2016<span class="noprint">; 5 years ago</span><span style="display:none"> (<span class="bday dtstart published updated">2016-08-18</span>)</span></td></tr><tr><th class="infobox-label" scope="row" style="line-height:1.3em">Split from</th><td class="infobox-data" style="line-height:1.3em">PAIS Alliance</td></tr><tr><th class="infobox-label" scope="row" style="line-height:1.3em">Headquarters</th><td class="infobox-data label" style="line-height:1.3em">Quito</td></tr><tr><th class="infobox-label" scope="row" style="line-height:1.3em">Youth wing</th><td class="infobox-data" style="line-height:1.3em"><i>Frente de Jóvenes de la RC</i></td></tr><tr><th class="infobox-label" scope="row" style="line-height:1.3em">Membership<span class="nobold">(2022)</span></th><td class="infobox-data" style="line-height:1.3em">200,000</td></tr><tr><th class="infobox-label" scope="row" style="line-height:1.3em">Ideology</th><td class="infobox-data category" style="line-height:1.3em"><div class="plainlist nowrap"><ul><li>Progressivism</li><li>Anti-neoliberalism</li><li>Socialism of the 21st century</li><li>Bolivarianism</li><li>Correism</li><li>Left-wing nationalism</li><li>Left-wing populism</li><li>Market socialism</li><li>Anti-imperialism</li></ul></div></td></tr><tr><th class="infobox-label" scope="row" style="line-height:1.3em">Political position</th><td class="infobox-data category" style="line-height:1.3em">Left-wing</td></tr><tr><th class="infobox-label" scope="row" style="line-height:1.3em">National affiliation</th><td class="infobox-data category" style="line-height:1.3em">Union for Hope</td></tr><tr><t ...
#       <td id="T_3ed7b_row0_col1" class="data row0 col1" >Irrelevant Context && The context provided does not give any information about Joe Biden's spouse during his first election to the Senate.</td>
#       <td id="T_3ed7b_row0_col2" class="data row0 col2" >Unmarried</td>
#       <td id="T_3ed7b_row0_col3" class="data row0 col3" >Who was Joe Biden married to when he was first elected to the Senate?</td>
#       <td id="T_3ed7b_row0_col4" class="data row0 col4" >Irrelevant Context</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_gpt4.query("predicted_answer.str.contains('relevant')").shape
# Out:
# (15, 5)

# %%
html_render_df(
    df_gpt4.query("predicted_answer_short != actual_answer")
    .sample(10, random_state=94)
    .loc[:, ["table", "question", "predicted_answer_short", "actual_answer"]]
)
# Out:
# <style type="text/css">
# #T_13e61_row0_col0, #T_13e61_row1_col0, #T_13e61_row2_col0, #T_13e61_row3_col0, #T_13e61_row4_col0, #T_13e61_row5_col0, #T_13e61_row6_col0, #T_13e61_row7_col0, #T_13e61_row8_col0, #T_13e61_row9_col0 {
#   text-align: left;
# }
# </style>
# <table id="T_13e61">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13e61_level0_col0" class="col_heading level0 col0" >table</th>
#       <th id="T_13e61_level0_col1" class="col_heading level0 col1" >question</th>
#       <th id="T_13e61_level0_col2" class="col_heading level0 col2" >predicted_answer_short</th>
#       <th id="T_13e61_level0_col3" class="col_heading level0 col3" >actual_answer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13e61_level0_row0" class="row_heading level0 row0" >719</th>
#       <td id="T_13e61_row0_col0" class="data row0 col0" ><div style="border: 1px solid #ddd; padding: 5px;"><table class="infobox vevent" style="border-collapse:collapse"><caption class="infobox-title">Hurricane Gaston</caption><tbody><tr><td class="infobox-subheader" colspan="2" style="font-weight:700;background-color:#fff795">Category 1 hurricane (SSHWS/NWS)</td></tr><tr><td class="infobox-image" colspan="2"><img alt="Gaston 2004-08-29 0710Z.jpg" data-file-height="4401" data-file-width="3400" decoding="async" height="337" src="https://upload.wikimedia.org/wikipedia/commons/thumb/b/ba/Gaston_2004-08-29_0710Z.jpg/260px-Gaston_2004-08-29_0710Z.jpg" srcset="https://upload.wikimedia.org/wikipedia/commons/thumb/b/ba/Gaston_2004-08-29_0710Z.jpg/390px-Gaston_2004-08-29_0710Z.jpg 1.5x,https: //upload.wikimedia.org/wikipedia/commons/thumb/b/ba/Gaston_2004-08-29_0710Z.jpg/520px-Gaston_2004-08-29_0710Z.jpg 2x" width="260"><div class="infobox-caption" style="border-bottom:#aaa 1px solid">Hurricane Gaston shortly after moving ashore on August 29</div></td></tr><tr><th class="infobox-label" scope="row" style="padding:0 2px;white-space:nowrap">Formed</th><td class="infobox-data" style="padding:0 2px">August 27, 2004</td></tr><tr><th class="infobox-label" scope="row" style="padding:0 2px;white-space:nowrap">Dissipated</th><td class="infobox-data" style="padding:0 2px">September 3, 2004</td></tr><tr><td class="infobox-full-data" colspan="2" style="padding:0 2px">(Extratropical after September 1)</td></tr><tr><td class="infobox-full-data" colspan="2" style="padding:0 2px"></td></tr><tr><td colspan="2" style="text-align:center;border-top:#aaa 1px solid"></td></tr><tr style="display:none"><td colspan="2"></td></tr><tr><th class="infobox-label" scope="row" style="padding:0 2px;white-space:nowrap">Highest winds</th><td class="infobox-data" style="padding:0 2px">1-minute sustained:<span class="nowrap">75 mph (120 km/h)</span><br></td></tr><tr><th class="infobox-label" scope="row" style="padding:0 2px;white-space:nowrap">Lowest pressure</th><td class="infobox-data" style="padding:0 2px">985 mbar (hPa); 29.09 inHg</td></tr><tr><td class="infobox-full-data" colspan="2" style="padding:0 2px"></td></tr><tr><td colspan="2" style="text-align:center;border-top:#aaa 1px solid"></td></tr><tr style="display:none"><td colspan="2"></td></tr><tr><th class="infobox-label" scope="row" style="padding:0 2px;white-space:nowrap">Fatalities</th><td class="infobox-data" style="padding:0 2px">8 direct, 1 indirect</td></tr><tr><th class="infobox-label" scope="row" style="padding:0 2px;white-space:nowrap">Damage</th><td class="infobox-data" style="padding:0 2px">$130 million (2004 USD)</td></tr><tr><th class="infobox-label" scope="row" style="padding:0 2px;white-space:nowrap">Areas affected</th><td class="infobox-data" style="padding:0 2px">South Carolina, North Carolina, Virginia, Maryland, Delaware, Massachusetts</td></tr><tr><td class="infobox-full-data" colspan="2" style="padding:0 2px"></td></tr><tr><td colspan="2" style="text-align:center;border-top:#aaa 1px solid">Part of the<b>2004 Atlantic hurricane season</b></td></tr><tr style="display:none"><td colspan="2"></td></tr></tbody></table></div></td>
#       <td id="T_13e61_row0_col1" class="data row0 col1" >When was Hurricane Gaston on the land?</td>
#       <td id="T_13e61_row0_col2" class="data row0 col2" >August 27 to September 3, 2004</td>
#       <td id="T_13e61_row0_col3" class="data row0 col3" >after August 29</td>
#     </tr>
#     <tr>
#       <th id="T_13e61_level0_row1" class="row_heading level0 row1" >930</th>
#       <td id="T_13e61_row1_col0" class="data row1 col0" ><div style="border: 1px solid #ddd; padding: 5px;"><table class="infobox" style="width:25.5em;border-spacing:2px"><tbody><tr><th class="infobox-above" colspan="2" style="background-color:#c3d6ef;text-align:center;vertical-align:middle;font-size:110%">Federal Defence Forces of Germany</th></tr><tr><td class="infobox-subheader" colspan="2" style="background-color:#dcdcdc;text-align:center;vertical-align:middle"><i>Bundeswehr</i></td></tr><tr><td class="infobox-image" colspan="2" style="text-align:center;border-bottom:1px solid #aaa;line-height:1.5em"><img alt="Logo of the Bundeswehr.svg" data-file-height="1074" data-file-width="1453" decoding="async" height="163" src="https://upload.wikimedia.org/wikipedia/commons/thumb/0/06/Logo_of_the_Bundeswehr.svg/220px-Logo_of_the_Bundeswehr.svg.png" srcset="https://upload.wikimedia.org/wikipedia/commons/thumb/0/06/Logo_of_the_Bundeswehr.svg/330px-Logo_of_the_Bundeswehr.svg.png 1.5x,https: //upload.wikimedia.org/wikipedia/commons/thumb/0/06/Logo_of_the_Bundeswehr.svg/440px-Logo_of_the_Bundeswehr.svg.png 2x" width="220"></td></tr><tr><th class="infobox-label" scope="row">Motto</th><td class="infobox-data"><i>Wir. Dienen. Deutschland.</i><br>(German for ''We. Serve. Germany.'')</td></tr><tr><th class="infobox-label" scope="row">Founded</th><td class="infobox-data">12 November 1955<span style="display:none"> (<span class="bday dtstart published updated">1955-11-12</span>)</span></td></tr><tr><th class="infobox-label" scope="row">Current form</th><td class="infobox-data">3 October 1990</td></tr><tr><th class="infobox-label" scope="row">Service branches</th><td class="infobox-data"><span class="flagicon"><img alt="" data-file-height="660" data-file-width="660" decoding="async" height="17" src="https://upload.wikimedia.org/wikipedia/commons/thumb/4/43/Truppenfahne_der_Bundeswehr.svg/17px-Truppenfahne_der_Bundeswehr.svg.png" srcset="https://upload.wikimedia.org/wikipedia/commons/thumb/4/43/Truppenfahne_der_Bundeswehr.svg/26px-Truppenfahne_der_Bundeswehr.svg.png 1.5x,https: //upload.wikimedia.org/wikipedia/commons/thumb/4/43/Truppenfahne_der_Bundeswehr.svg/34px-Truppenfahne_der_Bundeswehr.svg.png 2x" width="17"> </span>Army<br><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="1000" decoding="async" height="14" src="https://upload.wikimedia.org/wikipedia/commons/thumb/3/3e/Naval_Ensign_of_Germany.svg/23px-Naval_Ensign_of_Germany.svg.png" srcset="https://upload.wikimedia.org/wikipedia/commons/thumb/3/3e/Naval_Ensign_of_Germany.svg/35px-Naval_Ensign_of_Germany.svg.png 1.5x,https: //upload.wikimedia.org/wikipedia/commons/thumb/3/3e/Naval_Ensign_of_Germany.svg/46px-Naval_Ensign_of_Germany.svg.png 2x" width="23"> </span>Navy<br><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="1000" decoding="async" height="14" src="https://upload.wikimedia.org/wikipedia/commons/thumb/f/fb/Flag_of_Germany_%28state%29.svg/23px-Flag_of_Germany_%28state%29.svg.png" srcset="https://upload.wikimedia.org/wikipedia/commons/thumb/f/fb/Flag_of_Germany_%28state%29.svg/35px-Flag_of_Germany_%28state%29.svg.png 1.5x,https: //upload.wikimedia.org/wikipedia/commons/thumb/f/fb/Flag_of_Germany_%28state%29.svg/46px-Flag_of_Germany_%28state%29.svg.png 2x" width="23"> </span>Air Force<br><span class="nowrap"><img alt="Emblem of Streitkräftebasis" data-file-height="134" data-file-width="350" decoding="async" height="11" src="https://upload.wikimedia.org/wikipedia/commons/thumb/1/13/Bundeswehr_Logo_Streitkraeftebasis_w

# %%
# Some questions appear more than one time
df_gpt4.groupby("question").size().to_frame("occurences_of_same_question").groupby(
    "occurences_of_same_question"
).size()
# Out:
# occurences_of_same_question
# 1    975
# 2      3
# 4      2
# 5      4
# 6      3
# dtype: int64

# %%
df_gpt4[df_gpt4.duplicated(["question"], keep=False)].shape
# Out:
# (52, 5)

# %%
df_gpt4[df_gpt4.duplicated(["question", "actual_answer"], keep=False)].shape
# Out:
# (49, 5)

# %%
# Duplicate questions where question-actual_answer-pairs are not duplicated
(
    df_gpt4[df_gpt4.duplicated(["question"], keep=False)]  # Rows with duplicates only
    .drop_duplicates(
        subset=["question", "actual_answer"], keep=False
    )  # Remove (all) rows if Q and A are not unique
    .sort_values("question")
)
# Out:
#                                                  table  \
# 468  <html><body><table class="infobox" style="widt...
# 893  <table class="infobox" style="width:25.5em;bor...
# 938  <table class="infobox" style="width:25.5em;bor...
#
#                                       predicted_answer        actual_answer  \
# 468  26 years && HMS Somerset was commissioned in 1...             28 Years
# 893  8 years && HMS Astute has been in service sinc...  8 Years (from 2014)
# 938  Not applicable && The context given is about t...    A. J. Caleb Boggs
#
#                                               question predicted_answer_short
# 468  How many years does HMSAstute is service in UK...               26 years
# 893  How many years does HMSAstute is service in UK...                8 years
# 938  Who was the US senator from Delaware in Dec 1972?         Not applicable

# %%
# Different predicted answers for the same question-table pairs
df_gpt4[df_gpt4.duplicated(["question", "table"], keep=False)]
# Out:
#                                                  table  \
# 18   <html><body><table class="infobox ib-time-zone...
# 20   <html><body><table class="infobox ib-time-zone...
# 219  <html><body><table class="infobox vcard"><tbod...
# 221  <html><body><table class="infobox vcard"><tbod...
#
#                                       predicted_answer actual_answer  \
# 18   2 hours && Florida is in Eastern Time Zone and...     two hours
# 20   2 hours difference && Florida is in Eastern Ti...     two hours
# 219  25 years old && Futabayama Sadaji was born in ...            25
# 221  25 years old && Futabayama was born in 1912 an...            25
#
#                                               question predicted_answer_short
# 18   What's the difference in time between Florida ...                2 hours
# 20   What's the difference in time between Florida ...     2 hours difference
# 219  How old was Futabayama Sadaji when he achieved...           25 years old
# 221  How old was Futabayama Sadaji when he achieved...           25 years old

# %%
# Predicted answer and question are the same despite different tables
df_gpt4[df_gpt4.duplicated(["question", "predicted_answer"], keep=False)].sort_values(
    "question"
)
# Out:
#                                                  table  \
# 342  <html><body><table class="infobox vevent"><tbo...
# 728  <table class="infobox vevent" style="border-co...
# 345  <html><body><table class="infobox vevent"><tbo...
# 948  <table class="infobox" style="width:25.5em;bor...
#
#                                       predicted_answer  actual_answer  \
# 342  Neilia Hunter && Joe Biden was married to Neil...      Unmarried
# 728  Neilia Hunter && Joe Biden was married to Neil...      Unmarried
# 345  Not relevant && The context provided does not ...  Neilia Hunter
# 948  Not relevant && The context provided does not ...  Neilia Hunter
#
#                                               question predicted_answer_short
# 342  Who was Joe Biden married to when he was first...          Neilia Hunter
# 728  Who was Joe Biden married to when he was first...          Neilia Hunter
# 345      Who was the better half of Joe Biden in 1970?           Not relevant
# 948      Who was the better half of Joe Biden in 1970?           Not relevant

# %%
# Sanity check to see if table 342 and 345 are different
# (as prodced by this code: df_gpt4[df_gpt4.duplicated(["question", "predicted_answer"], keep=False)].sort_values("question"))
df_gpt4[df_gpt4.duplicated(["question", "predicted_answer", "table"], keep=False)]
# Out:
# Empty DataFrame
# Columns: [table, predicted_answer, actual_answer, question, predicted_answer_short]
# Index: []

# %%
# Duplicates may be due to different predicted answers or different context tables
df_gpt4[
    df_gpt4.duplicated(subset=["question", "actual_answer"], keep=False)
].sort_values(by="question").head()
# Out:
#                                                  table  \
# 908  <table class="infobox" style="width:25.5em;bor...
# 725  <table class="infobox vevent" style="border-co...
# 922  <table class="infobox" style="width:25.5em;bor...
# 845  <table class="infobox vevent"><tbody><tr><th c...
# 339  <html><body><table class="infobox vevent"><tbo...
#
#                                       predicted_answer actual_answer  \
# 908  Not available && The context provided is about...            27
# 725  Information not available && The context provi...            27
# 922  Not available && The context provided does not...            27
# 845  Unrelated context && The provided context does...            27
# 339  Not applicable && The context provided is not ...           one
#
#                                               question  \
# 908  At what age does Joe Biden join the democratic...
# 725  At what age does Joe Biden join the democratic...
# 922  At what age does Joe Biden join the democratic...
# 845  At what age does Joe Biden join the democratic...
# 339  How many parties does Joe’s Biden’s is associa...
#
#         predicted_answer_short
# 908              Not available
# 725  Information not available
# 922              Not available
# 845          Unrelated context
# 339             Not applicable

# %%
html_tables = os.listdir("../../data/maindata/tables/html/")
table_id_to_html = {}
for file in html_tables:
    with open(f"../../data/maindata/tables/html/{file}") as f:
        html = f.read()
    table_id = int(file.replace(".html", ""))
    table_id_to_html[table_id] = html
table_id_mapping = pd.DataFrame.from_dict(
    table_id_to_html, orient="index", columns=["table"]
).reset_index(names="table_id")
