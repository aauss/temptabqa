# %% [markdown]
# # Calculate temporal error on answers expecting "year" time unit

# %%
import numpy as np
import pandas as pd
import seaborn as sns

from utils import add_temp_errors, merge_with_indomain_year_only
from prediction_analysis import calc_final_scores

# %% [markdown]
# ## Load data
#
# First, I load my automatically labeled data on which time unit the expected answer has. Then, I load the results from GPT-4. Both are using few-shot and one uses CoT. The CoT results are better, but there are fewer examples matching with my dataset and extracting the answer from the CoT example is also harder.

# %%
head_gpt_fs_w_reas = pd.read_csv(
    "./../../models/predictions/gpt4/fewshot_with_reasoning/indomain_eval_gpt_4_few_shot_with_reasoning_single.csv"
)
head_gpt_fs_w_reas.shape
# Out:
# (1901, 4)

# %%
temp_err_df = merge_with_indomain_year_only(head_gpt_fs_w_reas)
temp_err_df.head()
# Out:
#                                             question        answer  table_id  \
# 0  How many years did Art Carney as actor since 1...      54 Years         2
# 1  How many total years was Art Carney married to...      28 years         2
# 2  How many years before he died was Art Carney m...            23         2
# 3  How old was Art Carney when he first got divor...            47         2
# 4        How many years ago did Art Carney was died?  19 Years ago         2
#
#                                     predicted_answer
# 0  54 years && Art Carney was active from 1939 to...
# 1  45 years && Art Carney was married to Jean Mye...
# 2  23 years && Art Carney remarried his first wif...
# 3  46 years old && Art was born in 1918 and got d...
# 4  19 years ago && Art Carney died in 2003, and c...

# %% [markdown]
# ## Transform data
#
# We need to extract and translate the number of years from expected and actual answer to integers. In this notebook, we will focus on answers that only expect one string of digit. This excludes several integer answers, ranges, etc.

# %%
temp_err_df = temp_err_df.assign(
    predicted_answer_wo_reas=lambda x: x["predicted_answer"]
    .str.split("&&")  # Seperate answer from reasoning
    .apply(lambda y: y[0]),
    answer_digits=lambda x: x["answer"].str.findall("\d+"),
    predicted_answer_digits=lambda x: x["predicted_answer_wo_reas"].str.findall("\d+"),
)
temp_err_df.head()
# Out:
#                                             question        answer  table_id  \
# 0  How many years did Art Carney as actor since 1...      54 Years         2
# 1  How many total years was Art Carney married to...      28 years         2
# 2  How many years before he died was Art Carney m...            23         2
# 3  How old was Art Carney when he first got divor...            47         2
# 4        How many years ago did Art Carney was died?  19 Years ago         2
#
#                                     predicted_answer predicted_answer_wo_reas  \
# 0  54 years && Art Carney was active from 1939 to...                54 years
# 1  45 years && Art Carney was married to Jean Mye...                45 years
# 2  23 years && Art Carney remarried his first wif...                23 years
# 3  46 years old && Art was born in 1918 and got d...            46 years old
# 4  19 years ago && Art Carney died in 2003, and c...            19 years ago
#
#   answer_digits predicted_answer_digits
# 0          [54]                    [54]
# 1          [28]                    [45]
# 2          [23]                    [23]
# 3          [47]                    [46]
# 4          [19]                    [19]

# %%
temp_err_df.shape
# Out:
# (858, 7)

# %% [markdown]
# Dealing with single digit answers is easier. Sometimes, lists of years or date ranges are expected. Will look at them later.

# %%
temp_err_single_digit_df = temp_err_df.query(
    "answer_digits.str.len()==1 and predicted_answer_digits.str.len()==1"
)
temp_err_single_digit_df.shape
# Out:
# (795, 7)

# %% [markdown]
# ## Calculate and plot error

# %%
temp_err_single_digit_df = add_temp_errors(temp_err_single_digit_df)
temp_err_single_digit_df.head()
# Out:
#                                             question        answer  table_id  \
# 0  How many years did Art Carney as actor since 1...      54 Years         2
# 1  How many total years was Art Carney married to...      28 years         2
# 2  How many years before he died was Art Carney m...            23         2
# 3  How old was Art Carney when he first got divor...            47         2
# 4        How many years ago did Art Carney was died?  19 Years ago         2
#
#                                     predicted_answer predicted_answer_wo_reas  \
# 0  54 years && Art Carney was active from 1939 to...                54 years
# 1  45 years && Art Carney was married to Jean Mye...                45 years
# 2  23 years && Art Carney remarried his first wif...                23 years
# 3  46 years old && Art was born in 1918 and got d...            46 years old
# 4  19 years ago && Art Carney died in 2003, and c...            19 years ago
#
#    answer_digits  predicted_answer_digits  err   rel_err  abs_err  \
# 0             54                       54    0  0.000000        0
# 1             28                       45   17  0.607143       17
# 2             23                       23    0  0.000000        0
# 3             47                       46   -1 -0.021277        1
# 4             19                       19    0  0.000000        0
#
#    abs_per_err   log_err
# 0     0.000000  0.000000
# 1    60.714286  0.461346
# 2     0.000000  0.000000
# 3     2.127660 -0.021053
# 4     0.000000  0.000000

# %% [markdown]
# ### Error in years

# %%
sns.set_theme(style="whitegrid")


ax = sns.boxenplot(
    temp_err_single_digit_df,
    y="err",
    color="b",
    width_method="linear",
    k_depth="proportion",
    outlier_prop=0.007,
)
ax.set_xlabel("Width is a scale free, linear rep. of amount of data")
ax.set_ylabel("Error in number of years")
# Out:
# Text(0, 0.5, 'Error in number of years')

# %%
sns.stripplot(
    data=temp_err_single_digit_df,
    y="err",
    alpha=0.4,
    legend=False,
)
ax.set_ylabel("Error in number of years")
# Out:
# Text(28.0, 0.5, 'Error in number of years')

# %%
ax = sns.boxenplot(
    temp_err_single_digit_df,
    y="err",
    color="b",
    width_method="linear",
    k_depth="trustworthy",
    outlier_prop=0.007,
    showfliers=False,
)
ax.set_yscale("symlog")
sns.stripplot(data=temp_err_single_digit_df, y="err", color="k", ax=ax)
# Out:
# <Axes: ylabel='err'>

# %%
temp_err_single_digit_df.query("err.abs() > 1000").loc[
    :, ["question", "answer", "predicted_answer_wo_reas"]
].values
# Out:
# array([['How long after "21st Century Breakdown" was the next single released?',
#         '1 year', 'Next single released in 2010 '],
#        ['What year was Wil Calhoun an executive producer of Friends?',
#         '2001', 'Season 7 '],
#        ['How long has V/Line been a corporation?', '19 years',
#         'since 2003 '],
#        ['How many years after the first publication of FATE was the second publication?',
#         '3', 'Same year, 2003 ']], dtype=object)

# %%
ax = sns.boxenplot(
    temp_err_single_digit_df.query("err.abs()<1900"),
    y="err",
    color="b",
    width_method="linear",
    k_depth="trustworthy",
    outlier_prop=0.007,
    showfliers=False,
)
# ax.set_yscale("symlog")
sns.stripplot(data=temp_err_single_digit_df.query("err.abs()<1900"), y="err", color="k", ax=ax)
# Out:
# <Axes: ylabel='err'>

# %%
ax = sns.boxenplot(
    temp_err_single_digit_df.query("err.abs()<1900"),
    y="err",
    color="b",
    width_method="linear",
    k_depth="trustworthy",
    outlier_prop=0.007,
    showfliers=False,
)
ax.set_yscale("symlog")
sns.stripplot(data=temp_err_single_digit_df.query("err.abs()<1900"), y="err", color="k", ax=ax)
# Out:
# <Axes: ylabel='err'>

# %%
temp_err_single_digit_df.query("err.abs() > 100 and err.abs() < 1900").loc[
    :, ["question", "answer", "predicted_answer_wo_reas"]
].values
# Out:
# array([['How many years after the Ethiopian was first established did Mekelle become capital?',
#         '601', '100 years '],
#        ['How many years longer was the time between  Hammadid dynasty and the Zayyanid dynasty and the Rustamid dynasty and the Zirid dynasty?',
#         '25', '241 years ']], dtype=object)

# %%
ax = sns.boxenplot(
    temp_err_single_digit_df.query("err.abs()<100"),
    y="err",
    color="b",
    width_method="linear",
    k_depth="trustworthy",
    outlier_prop=0.007,
    showfliers=False,
)
# ax.set_yscale("symlog")
sns.stripplot(data=temp_err_single_digit_df.query("err.abs()<100"), y="err", color="k", ax=ax)
# Out:
# <Axes: ylabel='err'>

# %%
ax = sns.boxenplot(
    temp_err_single_digit_df.query("err.abs()<100"),
    y="err",
    color="b",
    width_method="linear",
    k_depth="trustworthy",
    outlier_prop=0.007,
    showfliers=False,
)
ax.set_yscale("symlog")
sns.stripplot(data=temp_err_single_digit_df.query("err.abs()<100"), y="err", color="k", ax=ax)
# Out:
# <Axes: ylabel='err'>

# %%
ax = sns.countplot(x=np.where(temp_err_single_digit_df["err"] == 0, "Error of 0", "|Error| > 0"))

# %%
ax = sns.boxenplot(
    temp_err_single_digit_df.query("err.abs()<100 and err!=0"),
    y="err",
    color="b",
    width_method="linear",
    k_depth="trustworthy",
    outlier_prop=0.007,
    showfliers=False,
)
# ax.set_yscale("symlog")
sns.stripplot(
    data=temp_err_single_digit_df.query("err.abs()<100 and err!=0"), y="err", color="k", ax=ax
)
# Out:
# <Axes: ylabel='err'>

# %%
ax = sns.boxenplot(
    temp_err_single_digit_df.query("err.abs()<100 and err!=0"),
    y="err",
    color="b",
    width_method="linear",
    k_depth="trustworthy",
    outlier_prop=0.007,
    showfliers=False,
)
ax.set_yscale("symlog")
sns.stripplot(
    data=temp_err_single_digit_df.query("err.abs()<100 and err!=0"), y="err", color="k", ax=ax
)
# Out:
# <Axes: ylabel='err'>

# %%
ax = sns.countplot(
    x=np.where(temp_err_single_digit_df.query("err!=0")["err"] > 0, "Error > 0 ", "Error < 0")
)

# %% [markdown]
# ### Absolute error

# %%
ax = sns.boxenplot(
    temp_err_single_digit_df,
    y="abs_err",
    color="b",
    width_method="linear",
    k_depth="proportion",
    outlier_prop=0.007,
)
ax.set_xlabel("Width is a scale free, linear rep. of amount of data")
# Out:
# Text(0.5, 0, 'Width is a scale free, linear rep. of amount of data')

# %%
ax = sns.boxenplot(
    temp_err_single_digit_df.query("abs_err <100"),
    y="abs_err",
    color="b",
    width_method="linear",
    k_depth="proportion",
    outlier_prop=0.007,
)
ax.set_xlabel("Width is a scale free, linear rep. of amount of data")
# Out:
# Text(0.5, 0, 'Width is a scale free, linear rep. of amount of data')

# %% [markdown]
# ### Absolute percentage error

# %%
ax = sns.boxenplot(
    temp_err_single_digit_df.query("abs_err < 100"),
    y="abs_per_err",
    color="b",
    width_method="linear",
    k_depth="proportion",
    outlier_prop=0.007,
)
ax.set_xlabel("Width is a scale free, linear rep. of amount of data")
ax.set_yscale("log")

# %% [markdown]
# ### Relative error

# %%
ax = sns.boxenplot(
    temp_err_single_digit_df.query("err.abs() < 100"),
    y="rel_err",
    color="b",
    width_method="linear",
    k_depth="trustworthy",
    outlier_prop=0.007,
    showfliers=False,
)
# ax.set_yscale("symlog")
sns.stripplot(data=temp_err_single_digit_df.query("err.abs()<200"), y="rel_err", color="k", ax=ax)
# Out:
# <Axes: ylabel='rel_err'>

# %%
rel_error = temp_err_single_digit_df.rel_err
print(np.mean(rel_error[rel_error > 0]))
print(np.mean(rel_error[rel_error < 0]))
# Out:
# 39.46558984181818
# -0.16645870382775016

# %%
np.mean(rel_error)
# Out:
# 3.6035005953365564

# %%
temp_err_single_digit_df.loc[:, "err"].value_counts().loc[:10]
# Out:
# err
#  0     603
# -1      72
#  1      27
#  2       9
#  4       8
# -2       6
# -6       5
# -3       5
#  10      5
# Name: count, dtype: int64

# %%
temp_err_single_digit_df.loc[:, "abs_err"].value_counts().loc[:15]
# Out:
# abs_err
# 0     603
# 1      99
# 2      15
# 4      11
# 10      9
# 3       6
# 6       6
# 7       6
# 15      4
# Name: count, dtype: int64

# %%
temp_err_single_digit_df.query("abs_err > 500").loc[:, "abs_err"]
# Out:
# 28      501
# 748    2009
# 765    1994
# 801    1984
# 844    2000
# Name: abs_err, dtype: int64

# %% [markdown]
# ### Log error

# %%
ax = sns.boxenplot(
    temp_err_single_digit_df,
    y="log_err",
    color="b",
    width_method="linear",
    k_depth="trustworthy",
    outlier_prop=0.007,
    showfliers=False,
)
# ax.set_yscale("symlog")
sns.stripplot(data=temp_err_single_digit_df, y="log_err", color="k", ax=ax)
# Out:
# <Axes: ylabel='log_err'>

# %%
temp_err_single_digit_df.head()
# Out:
#                                             question        answer  table_id  \
# 0  How many years did Art Carney as actor since 1...      54 Years         2
# 1  How many total years was Art Carney married to...      28 years         2
# 2  How many years before he died was Art Carney m...            23         2
# 3  How old was Art Carney when he first got divor...            47         2
# 4        How many years ago did Art Carney was died?  19 Years ago         2
#
#                                     predicted_answer predicted_answer_wo_reas  \
# 0  54 years && Art Carney was active from 1939 to...                54 years
# 1  45 years && Art Carney was married to Jean Mye...                45 years
# 2  23 years && Art Carney remarried his first wif...                23 years
# 3  46 years old && Art was born in 1918 and got d...            46 years old
# 4  19 years ago && Art Carney died in 2003, and c...            19 years ago
#
#    answer_digits  predicted_answer_digits  err   rel_err  abs_err  \
# 0             54                       54    0  0.000000        0
# 1             28                       45   17  0.607143       17
# 2             23                       23    0  0.000000        0
# 3             47                       46   -1 -0.021277        1
# 4             19                       19    0  0.000000        0
#
#    abs_per_err   log_err
# 0     0.000000  0.000000
# 1    60.714286  0.461346
# 2     0.000000  0.000000
# 3     2.127660 -0.021053
# 4     0.000000  0.000000

# %%
calc_final_scores(temp_err_single_digit_df.rename(columns={"answer": "actual_answer"}))
# Out:
# {'f1': 76.54285924587151,
#  'EM': 74.84276729559748,
#  'ROUGE1': 0.765773081690314,
#  'ROUGE2': 0.7656919293267513,
#  'METERO': 0.5504874428867973}
