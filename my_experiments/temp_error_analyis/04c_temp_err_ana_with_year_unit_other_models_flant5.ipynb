# %%
import pandas as pd
import spacy

from utils import cardinal_to_digit, merge_with_indomain_year_only
nlp = spacy.load("en_core_web_trf")

# %%
df = pd.read_csv(
    "./../temp_error_analyis/label_temp_answers_head_dataset/data/notebook_output/03_label_answers_with_year_timeunit_head_data.csv"
).query("answer_timeunit == 'year'")
df.head()
# Out:
#                                             question        answer  table_id  \
# 0  How many years did Art Carney as actor since 1...      54 Years         2
# 1  How many total years was Art Carney married to...      28 years         2
# 2  How many years before he died was Art Carney m...            23         2
# 3  How old was Art Carney when he first got divor...            47         2
# 4        How many years ago did Art Carney was died?  19 Years ago         2
#
#   answer_type  is_temporal    answer_old answer_timeunit
# 0    TEMPORAL  Is temporal      54 Years            year
# 1    TEMPORAL  Is temporal      28 years            year
# 2       COUNT  Is temporal            23            year
# 3         AGE  Is temporal            47            year
# 4    TEMPORAL  Is temporal  19 Years ago            year

# %%
flant5 = pd.read_csv(
    "./../../models/predictions/flant5/flant5_xxl/fewshot_with_reasoning/indomain_eval_flant5_xxl_few_shot_reasoning.csv"
).drop(columns="Unnamed: 0")
flant5.shape
# Out:
# (1901, 4)

# %%
df.merge(flant5, on="question", how="inner").shape
# Out:
# (859, 10)

# %%
temp_err_df = merge_with_indomain_year_only(flant5)

# %%
temp_err_df = temp_err_df.assign(
    predicted_answer_old=lambda x: x["predicted_answer"],
    predicted_answer=lambda x: x["predicted_answer_old"].apply(lambda y: cardinal_to_digit(y)),
    answer_digits=lambda x: x["answer"].str.findall("\d+"),
    predicted_answer_digits=lambda x: x["predicted_answer"].str.findall("\d+"),
)
temp_err_df.head()
# Out:
#                                             question        answer  table_id  \
# 0  How many years did Art Carney as actor since 1...      54 Years         2
# 1  How many total years was Art Carney married to...      28 years         2
# 2  How many years before he died was Art Carney m...            23         2
# 3  How old was Art Carney when he first got divor...            47         2
# 4        How many years ago did Art Carney was died?  19 Years ago         2
#
#                                     predicted_answer  \
# 0  Art Carney was an actor from 1939 to 1993. The...
# 1  Jean Myers and Art Carney were married for a t...
# 2  The last time Art Carney was married was in 19...
# 3  The first marriage of Art Carney was to Jean M...
# 4  Art Carney died on November 9, 2003, at the ag...
#
#                                 predicted_answer_old answer_digits  \
# 0  Art Carney was an actor from 1939 to 1993. The...          [54]
# 1  Jean Myers and Art Carney were married for a t...          [28]
# 2  The last time Art Carney was married was in 19...          [23]
# 3  The first marriage of Art Carney was to Jean M...          [47]
# 4  Art Carney died on November 9, 2003, at the ag...          [19]
#
#   predicted_answer_digits
# 0        [1939, 1993, 54]
# 1                [40, 65]
# 2            [1977, 2003]
# 3                  [1940]
# 4       [9, 2003, 85, 15]

# %%
temp_err_single_digit = temp_err_df.query("answer_digits.str.len()==1").assign(
    expected_minus_pred=lambda x: x["answer_digits"].apply(set)
    - x["predicted_answer_digits"].apply(set),
    has_overlap=lambda x: x["expected_minus_pred"].apply(len) == 0,
)
temp_err_single_digit.shape
# Out:
# (855, 9)

# %%
temp_err_single_digit.query("answer_digits.str.len()==1 and answer_digits==predicted_answer_digits").shape
# Out:
# (53, 9)

# %%
temp_err_single_digit.query("has_overlap == True").shape
# Out:
# (184, 9)

# %%
temp_err_single_digit.query("has_overlap != True and answer_digits!=predicted_answer_digits").shape
# Out:
# (671, 9)

# %%
temp_err_single_digit.query("has_overlap != True and answer_digits!=predicted_answer_digits").loc[
    :, ["question", "predicted_answer", "answer_digits", "predicted_answer_digits", "has_overlap"]
]
# Out:
#                                               question  \
# 1    How many total years was Art Carney married to...
# 2    How many years before he died was Art Carney m...
# 3    How old was Art Carney when he first got divor...
# 4          How many years ago did Art Carney was died?
# 5    For how many years had Benedict Cumberbatch be...
# ..                                                 ...
# 851  How many years difference was there between th...
# 852  How long did Sri Lanka take from being an ICC ...
# 853  How long did it take for Sri Lanka to become a...
# 855  How long after Sri Lanka's first ODI and first...
# 856  What is the time span for World Test Champions...
#
#                                       predicted_answer answer_digits  \
# 1    Jean Myers and Art Carney were married for a t...          [28]
# 2    The last time Art Carney was married was in 19...          [23]
# 3    The first marriage of Art Carney was to Jean M...          [47]
# 4    Art Carney died on November 9, 2003, at the ag...          [19]
# 5    Benedict Cumberbatch has been acting for 15 ye...          [17]
# ..                                                 ...           ...
# 851  reasoning. The answer is : First T20I v | West...          [40]
# 852  1965 | ) Best result Quarter-finalist (2019-2021)          [16]
# 853  Sri Lanka was an Associate Member of the ICC f...          [16]
# 855       1975 | ) T20Is First T20I v | West Indies at          [31]
# 856                                          2019-2021           [2]
#
#     predicted_answer_digits  has_overlap
# 1                  [40, 65]        False
# 2              [1977, 2003]        False
# 3                    [1940]        False
# 4         [9, 2003, 85, 15]        False
# 5                [15, 2015]        False
# ..                      ...          ...
# 851                    [20]        False
# 852      [1965, 2019, 2021]        False
# 853         [1965, 1981, 6]        False
# 855          [1975, 20, 20]        False
# 856            [2019, 2021]        False
#
# [671 rows x 5 columns]

# %%
# Reference for definitions: https://www.newscatcherapi.com/blog/named-entity-recognition-with-spacy
ENTS_OF_INTEREST = [
    "CARDINAL",
    "TIME",
    "DATE"
]

# %%
temp_err_single_digit = temp_err_single_digit.assign(
    predicted_answer_nlp=lambda x: x["predicted_answer"].apply(nlp),
    answer_nlp=lambda x: x["answer"].apply(nlp),
    predicted_answers_ents=lambda x: x["predicted_answer_nlp"].apply(
        lambda doc: [ent for ent in doc.ents if ent.label_ in ENTS_OF_INTEREST]
    ),
    predicted_answers_ent_labels=lambda x: x["predicted_answers_ents"].apply(
        lambda ents: [ent.label_ for ent in ents]
    ),
    answers_ents=lambda x: x["answer_nlp"].apply(lambda doc: [ent for ent in doc.ents]),
    answers_ent_labels=lambda x: x["answers_ents"].apply(lambda ents: [ent.label_ for ent in ents]),
)

# %%
temp_err_single_digit_small = (
    temp_err_single_digit.drop(
        columns=[
            # "question",
            "predicted_answer_old",
            "predicted_answer_nlp",
            "answer_nlp",
            "expected_minus_pred",
        ]
    )
    .query("has_overlap == False")
    .drop(columns="has_overlap")
)
temp_err_single_digit_small.loc[2].predicted_answer
# Out:
# 'The last time Art Carney was married was in 1977. He died in 2003. So,'

# %% [markdown]
# ## Pos
# - Q: 'How many years did Art Carney as actor since 1939?'
# - P: 'Art Carney was an actor from 1939 to 1993. The answer is 54.'
# - E: '54 Years'
#
# ## Neg but right temporal unit
# - Q: 'How long did it take for Sri Lanka to become a full member after attaining its Associate Member ICC status?'
# - P: 'Sri Lanka was an Associate Member of the ICC from 1965 to 1981. The answer is 6.'
# - E: '16 years'
#
# ## Entirely false
# - Q: 'How many years before he died was Art Carney married for the last time?'
# - P: 'The last time Art Carney was married was in 1977. He died in 2003. So,'
# - E: '23'

# %%
temp_err_single_digit_small.assign(
    ent_overlap=lambda x: x["predicted_answers_ent_labels"].apply(set)
    & x["answers_ent_labels"].apply(set)
).query("ent_overlap == False").shape
# Out:
# (276, 11)

# %%
# Examples for testing on cluster
temp_err_single_digit.loc[[3,4, 13]]
# Out:
#                                              question        answer  table_id  \
# 3   How old was Art Carney when he first got divor...            47         2
# 4         How many years ago did Art Carney was died?  19 Years ago         2
# 13  How many years long was Dwayne Johnson's profe...            23         7
#
#                                      predicted_answer  \
# 3   The first marriage of Art Carney was to Jean M...
# 4   Art Carney died on November 9, 2003, at the ag...
# 13  Dwayne Johnson retired in 2019 after a career ...
#
#                                  predicted_answer_old answer_digits  \
# 3   The first marriage of Art Carney was to Jean M...          [47]
# 4   Art Carney died on November 9, 2003, at the ag...          [19]
# 13  Dwayne Johnson retired in 2019 after a career ...          [23]
#
#    predicted_answer_digits expected_minus_pred  has_overlap  \
# 3                   [1940]                {47}        False
# 4        [9, 2003, 85, 15]                {19}        False
# 13              [2019, 23]                  {}         True
#
#                                  predicted_answer_nlp        answer_nlp  \
# 3   (The, first, marriage, of, Art, Carney, was, t...              (47)
# 4   (Art, Carney, died, on, November, 9, ,, 2003, ...  (19, Years, ago)
# 13  (Dwayne, Johnson, retired, in, 2019, after, a,...              (23)
#
#                                predicted_answers_ents  \
# 3                                            [(1940)]
# 4   [(November, 9, ,, 2003), (the, age, of, 85), (...
# 13                              [(2019), (23, years)]
#
#    predicted_answers_ent_labels        answers_ents answers_ent_labels
# 3                        [DATE]              [(47)]         [CARDINAL]
# 4            [DATE, DATE, DATE]  [(19, Years, ago)]             [DATE]
# 13                 [DATE, DATE]              [(23)]         [CARDINAL]

# %%
temp_err_single_digit.query("has_overlap==False").loc[4].predicted_answer
# Out:
# 'Art Carney died on November 9, 2003, at the age of 85. The answer is 15'
